# %%
'''processing and prediction '''
# author: jyu29
# create time: 2021-08

# read latest row number since last prediction
import pandas as pd
import psycopg2
from sqlalchemy import create_engine 
import jieba
import joblib
import re
import os
import warnings
import datetime
import keras
from tensorflow.python.keras.preprocessing import sequence,text
import time 
import logging
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
def warn(*args, **kwargs):
    pass
warnings.warn = warn
logging.getLogger('tensorflow').disabled = True



def read_max_seq():
    with open(r'/data/project/invalid_remark/max_seq_id.txt','r') as f:
        max_id=f.read()
#     print(max_id)
    return max_id

# query data from datamart
def load_channel_data_with_seq(start_id):
    conn = psycopg2.connect(database="dw", user="text_miner", password="gQ@8fwta2pFtZayxxi", host="10.50.8.227", port="60906")
    c= conn.cursor()
    sql="""select seq_id, customer_remark, "remark_Info" from smartdata_pro.f_invalide_customer_remark where seq_id>=%d;"""%start_id
    c.execute(sql)
    data=c.fetchall()
    #print(data)
    raw_remarks=[]
    for item in data:
        temp_list=list(item[0:2])
        temp_json=eval(item[2])[0]
        temp_list.extend([temp_json['commentsType'],temp_json['channel']])
        temp_tuple=tuple(temp_list)
        raw_remarks.append(temp_tuple)
    
    raw_remarks=pd.DataFrame(raw_remarks,columns=['seq_id','custom_mark','comments_Type','channel'])
        
    #raw_remark=pd.DataFrame(c.fetchall(),columns=['seq_id','custom_mark','remark_info'])
    conn.close()
    
    return raw_remarks

# load stopwords
def load_stopword():
#     jieba.load_userdict(r"/data/jyu29/nlp/text classfication/ilsten/data/stopwordmaster.txt")
    jieba.load_userdict(r"/data/jyu29/nlp/text classfication/ilsten/data/dictionary/joe_remark_dict.txt")

    with open(r'/data/jyu29/nlp/text classfication/ilsten/data/stopword.txt',encoding='utf8') as f:
        line_list=f.readlines()
        stopword_list=[k.strip() for k in line_list]
        stopword_set=set(stopword_list)
#         print('停顿词列表，即变量stopword_list中共有%d个元素' %len(stopword_list))
#         print('停顿词集合，即变量stopword_set中共有%d个元素' %len(stopword_set))
    return stopword_set

# remove blanks
def blank_rm(blist:list):
    """去除list中的空格项/remove blank items in the list"""
    newlist=[]
    for item in blist:
       if (item != '') and (item!=' '):
           newlist.append(item)
    
    return newlist

# wordcut and clean text
def remove_punctuation(line):
    line = str(line)
    if line.strip()=='':
        return ''
    rule = re.compile(u"[^a-zA-Z0-9\u4E00-\u9FA5]")
    line = rule.sub('',line)
    return line



# load tokenizer and transform data into sequence data
def convert_text_to_sequence(input_text):
    token = joblib.load('/data/jyu29/nlp/text classfication/dataFile_0922.pkl')
    text_sequence = token.texts_to_sequences(input_text)
    pad_text_sequence = sequence.pad_sequences(text_sequence)
    
#     sequence_text = tokenized_text.texts_to_sequences(tokenized_text)
    return pad_text_sequence

# update prediction to datalake
def update_table(data): 
    input_data=[]
    for ind, items in data.iterrows():
        input_data.append(tuple(items))       
        
    conn = psycopg2.connect(database="dw", user="text_miner", password="gQ@8fwta2pFtZayxxi", host="10.50.8.227", port="60906")

    c= conn.cursor()
    
    c.execute("""
    update smartdata_pro.f_invalide_customer_remark as f
    set 
    invalid_remark=s.invalid_remark
    from unnest(%s) s(seq_id integer,invalid_remark integer)
    where f.seq_id=s.seq_id
    """,(input_data,))
    
    conn.commit()
    
    c.execute("""
              update smartdata_pro.f_invalide_customer_remark
set invalid_remark=0
where customer_remark like '%黑边%'""")
    conn.commit()
    conn.close()
    print('database is updated!')
    
def save_max_seq(max_seq):
    with open(r'/data/project/invalid_remark/max_seq_id.txt','w') as f:
        f.write(max_seq)
    print('Save max seq_id in file')
    print('-------------------------------------------------------------------------')
#     print(max_seq)


#     with open(r'/data/project/invalid_remark/max_seq_id.txt','r') as f:




def predict_binary_class(yhat):
    yhat[yhat<=0.5]=0
    yhat[yhat>0.5]=1
    return yhat


def user_comment_predict(data):
    rnnmodel = keras.models.load_model('/data/jyu29/nlp/text classfication/invalid_remark/model/rnnmodel_0922.h5')
#     print ('Model loaded')
            #query = query.reindex(columns=model_columns, fill_value=0)
    stopword = load_stopword()
    data = data.fillna('谢谢老板')
    data['clean_text'] = data['custom_mark'].apply(remove_punctuation)

    data['cut_text'] = data['clean_text'].apply(lambda x: " ".join([w for w in list(jieba.cut(x)) if w not in stopword]))
    
    ### manual add rule ###
    data.loc[data['cut_text'].str.contains('AG'), 'cut_text'] = '谢谢 老板'
    
    print('clean_text:',data['cut_text'].values)
    sequence_data = convert_text_to_sequence(data['cut_text'])
    
    try:
    
        prediction = rnnmodel.predict(sequence_data)
        yhat = int(predict_binary_class(prediction))
        data['invalid_remark'] = yhat
    except Exception as e:
        data['invalid_remark'] = 1
    
    return data[['seq_id','invalid_remark']]

# def customer_service_predict(data):
#     rnnmodel = keras.models.load_model('/data/jyu29/nlp/text classfication/invalid_remark/model/rnnmodel_0922.h5')
# #     print ('Model loaded')
#             #query = query.reindex(columns=model_columns, fill_value=0)
#     stopword = load_stopword()
#     data = data.fillna('谢谢老板')
#     data['clean_text'] = data['custom_mark'].apply(remove_punctuation)

#     data['cut_text'] = data['clean_text'].apply(lambda x: " ".join([w for w in list(jieba.cut(x)) if w not in stopword]))
#     print('clean_text:',data['cut_text'].values)

#     sequence_data = convert_text_to_sequence(data['cut_text'])
#     try:
    
#         prediction = rnnmodel.predict(sequence_data)
#         yhat = int(predict_binary_class(prediction))
#         data['invalid_remark'] = yhat
#     except Exception as e:
#         data['invalid_remark'] = 1
#     return data[['seq_id','invalid_remark']]


def predict_all_kinds(data):
    """devide data into two groups user comment and customer service comment;
    try to predict by seperate models then merge them """
#     data_customer=data[data['comments_Type']==1]
#     data_service=data[data['comments_Type']==2]
    if len(data)==0:
        print('no user comment update,the run time is ',datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        result_user=pd.DataFrame(columns=['seq_id','invalid_remark'])
    else:
        result_user=user_comment_predict(data)
    
#     if len(data_service)==0:
#         print('No customer service update, the runtime is ',datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
#         result_customer=pd.DataFrame(columns=['seq_id','invalid_remark'])
#     else:
#         result_customer=customer_service_predict(data_service)
        #print(result_customer)
    
#     result_all=result_user.append(result_customer,ignore_index=True)
    result_all = result_user
#     result_all.reset_index(drop=True,inplace=True)
    result_all.seq_id = result_all.seq_id.astype(int)
    result_all.invalid_remark = result_all.invalid_remark.astype(int)

    
    return result_all
    



def predict_and_update():
    max_seq_id=read_max_seq()
#     print(max_seq_id)
    start_id=int(max_seq_id)+1
 
    try:
        query=load_channel_data_with_seq(start_id=start_id)
#         print(query)
        data_len=len(query)
    
        if data_len>0:
            final_result=predict_all_kinds(query)
            print(final_result)
            max_id=final_result['seq_id'].max()
                   
            update_table(final_result)
            save_max_seq(str(max_id))
            
    except Exception as e:
        print(str(e))
                
            
        
def timer(n):
    while True:
        predict_and_update()
#         print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        time.sleep(n)
    
if __name__=='__main__':
    
    warnings.filterwarnings('ignore')
    print('the process id:',os.getpid())
    timer(10)
# Out:
# the process id: 24480
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.634 seconds.
# Prefix dict has been built successfully.
# clean_text: ['ywd14583']
#    seq_id  invalid_remark
# 0  523297               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['請 不要 分開 包裹 寄要 一個 包裹 寄出 一個 包裹 寄出 一個 包裹 寄出 否則 差評 謝謝']
#    seq_id  invalid_remark
# 0  523298               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523299               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['尽快 发货 检查 好 质量 做工 谢谢']
#    seq_id  invalid_remark
# 0  523300               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['城 次日 达']
#    seq_id  invalid_remark
# 0  523301               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['寄 顺丰']
#    seq_id  invalid_remark
# 0  523302               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2165580938088839408']
#    seq_id  invalid_remark
# 0  523303               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2159777737977177924']
#    seq_id  invalid_remark
# 0  523304               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2071952427052503373']
#    seq_id  invalid_remark
# 0  523305               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2048895138068624624']
#    seq_id  invalid_remark
# 0  523306               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2161758492516067345']
#    seq_id  invalid_remark
# 0  523307               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2164555046429376468']
#    seq_id  invalid_remark
# 0  523308               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2162845837693924702']
#    seq_id  invalid_remark
# 0  523309               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1990539432277186589']
#    seq_id  invalid_remark
# 0  523310               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2159254693504019831']
#    seq_id  invalid_remark
# 0  523311               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1414232473038149388']
#    seq_id  invalid_remark
# 0  523312               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2145914712437913163']
#    seq_id  invalid_remark
# 0  523313               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 1327683928592279286' '不要 发 圆通 快递 谢谢']
#    seq_id  invalid_remark
# 0  523314               1
# 1  523315               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2171157950719303465']
#    seq_id  invalid_remark
# 0  523316               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['尽量 发同款 谢谢']
#    seq_id  invalid_remark
# 0  523317               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2172616309421756065']
#    seq_id  invalid_remark
# 0  523318               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
#    seq_id  invalid_remark
# 0  523324               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2172927024703001359']
#    seq_id  invalid_remark
# 0  523325               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2050288156010269913']
#    seq_id  invalid_remark
# 0  523326               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1973868014491765628']
#    seq_id  invalid_remark
# 0  523327               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2172462624222150446' '直赔 15 元 瑕疵 迪 小拳 20211014190038']
#    seq_id  invalid_remark
# 0  523328               1
# 1  523329               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2100804229757177839']
#    seq_id  invalid_remark
# 0  523330               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2159549715525526216']
#    seq_id  invalid_remark
# 0  523331               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['直赔 15 元 瑕疵 迪 小拳 20211014190038 已直 赔 15 谢春燕 1014' '2160341678187149764']
#    seq_id  invalid_remark
# 0  523332               1
# 1  523333               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2157231025545478021']
#    seq_id  invalid_remark
# 0  523334               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2168997516264395650']
#    seq_id  invalid_remark
# 0  523335               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2176985736275923813']
#    seq_id  invalid_remark
# 0  523336               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2161222130094844220']
#    seq_id  invalid_remark
# 0  523337               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1764204699322063021']
#    seq_id  invalid_remark
# 0  523338               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1409948619731872283']
#    seq_id  invalid_remark
# 0  523339               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2165431539668027514']
#    seq_id  invalid_remark
# 0  523340               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2158281468308279208']
#    seq_id  invalid_remark
# 0  523341               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2161116434945886707']
#    seq_id  invalid_remark
# 0  523342               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2162500095761911805']
#    seq_id  invalid_remark
# 0  523343               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1414144922212852079']
#    seq_id  invalid_remark
# 0  523344               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['深灰 抗极寒 大衣']
#    seq_id  invalid_remark
# 0  523345               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2164258586866201003']
#    seq_id  invalid_remark
# 0  523346               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1415199579071922688']
#    seq_id  invalid_remark
# 0  523347               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2171212526654231378']
#    seq_id  invalid_remark
# 0  523348               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2165302081031894143']
#    seq_id  invalid_remark
# 0  523349               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['202110040910006745']
#    seq_id  invalid_remark
# 0  523350               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2167568893112797618']
#    seq_id  invalid_remark
# 0  523351               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2163545641248159125']
#    seq_id  invalid_remark
# 0  523352               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2161023085387115034']
#    seq_id  invalid_remark
# 0  523353               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2170309322788180352']
#    seq_id  invalid_remark
# 0  523354               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1404599809011269882']
#    seq_id  invalid_remark
# 0  523355               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2168464359712197659']
#    seq_id  invalid_remark
# 0  523356               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 尽快 发货 急用 谢谢' '顺丰 寄付 2174086801410261246']
#    seq_id  invalid_remark
# 0  523357               1
# 1  523358               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2175387051297465459']
#    seq_id  invalid_remark
# 0  523359               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2152541520547207009']
#    seq_id  invalid_remark
# 0  523360               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2169831675495603428']
#    seq_id  invalid_remark
# 0  523361               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2165580938088839408']
#    seq_id  invalid_remark
# 0  523362               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2159777737977177924']
#    seq_id  invalid_remark
# 0  523363               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2071952427052503373' '2048895138068624624']
#    seq_id  invalid_remark
# 0  523364               1
# 1  523365               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2161758492516067345']
#    seq_id  invalid_remark
# 0  523366               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2164555046429376468' '2162845837693924702']
#    seq_id  invalid_remark
# 0  523367               1
# 1  523368               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1990539432277186589']
#    seq_id  invalid_remark
# 0  523369               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2159254693504019831']
#    seq_id  invalid_remark
# 0  523370               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1414232473038149388' '2145914712437913163']
#    seq_id  invalid_remark
# 0  523371               1
# 1  523372               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 1327683928592279286']
#    seq_id  invalid_remark
# 0  523373               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2171157950719303465' '顺丰 寄付 2172616309421756065']
#    seq_id  invalid_remark
# 0  523374               1
# 1  523375               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1336352328201569339']
#    seq_id  invalid_remark
# 0  523376               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2164767230181524664' '2160762771068245747']
#    seq_id  invalid_remark
# 0  523377               1
# 1  523378               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2127867986673955208']
#    seq_id  invalid_remark
# 0  523379               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2172927024703001359' '顺丰 寄付 2050288156010269913']
#    seq_id  invalid_remark
# 0  523380               1
# 1  523381               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1973868014491765628']
#    seq_id  invalid_remark
# 0  523382               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2172462624222150446' '顺丰 寄付 2100804229757177839']
#    seq_id  invalid_remark
# 0  523383               1
# 1  523384               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2159549715525526216']
#    seq_id  invalid_remark
# 0  523385               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2160341678187149764' '2157231025545478021']
#    seq_id  invalid_remark
# 0  523386               1
# 1  523387               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2168997516264395650']
#    seq_id  invalid_remark
# 0  523388               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2176985736275923813']
#    seq_id  invalid_remark
# 0  523389               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2161222130094844220' '1764204699322063021']
#    seq_id  invalid_remark
# 0  523390               1
# 1  523391               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1409948619731872283']
#    seq_id  invalid_remark
# 0  523392               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2165431539668027514' '2158281468308279208']
#    seq_id  invalid_remark
# 0  523393               1
# 1  523394               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2161116434945886707']
#    seq_id  invalid_remark
# 0  523395               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2162500095761911805' '1414144922212852079']
#    seq_id  invalid_remark
# 0  523396               1
# 1  523397               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2164258586866201003']
#    seq_id  invalid_remark
# 0  523398               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1415199579071922688']
#    seq_id  invalid_remark
# 0  523399               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2171212526654231378' '2165302081031894143']
#    seq_id  invalid_remark
# 0  523400               1
# 1  523401               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['202110040910006745']
#    seq_id  invalid_remark
# 0  523402               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2167568893112797618' '2163545641248159125']
#    seq_id  invalid_remark
# 0  523403               1
# 1  523404               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2161023085387115034']
#    seq_id  invalid_remark
# 0  523405               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2170309322788180352' '1404599809011269882']
#    seq_id  invalid_remark
# 0  523406               1
# 1  523407               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2168464359712197659']
#    seq_id  invalid_remark
# 0  523408               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2174086801410261246']
#    seq_id  invalid_remark
# 0  523409               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2175387051297465459' '顺丰 寄付 2152541520547207009']
#    seq_id  invalid_remark
# 0  523410               1
# 1  523411               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 寄付 2169831675495603428']
#    seq_id  invalid_remark
# 0  523412               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224162211386 换货 补发']
#    seq_id  invalid_remark
# 0  523415               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['快递 放 行政 楼']
#    seq_id  invalid_remark
# 0  523416               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请发 邮政 快递 快递 学校 无法 签收']
#    seq_id  invalid_remark
# 0  523417               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['不要 发 EMS']
#    seq_id  invalid_remark
# 0  523418               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 224191918398']
#    seq_id  invalid_remark
# 0  523419               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225205564454']
#    seq_id  invalid_remark
# 0  523420               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224849494281']
#    seq_id  invalid_remark
# 0  523421               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 卖家 保证质量 发对 型号 谢谢' '224955495496']
#    seq_id  invalid_remark
# 0  523422               1
# 1  523423               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225102131246']
#    seq_id  invalid_remark
# 0  523424               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224322490200']
#    seq_id  invalid_remark
# 0  523425               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225300873505']
#    seq_id  invalid_remark
# 0  523426               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224429285402']
#    seq_id  invalid_remark
# 0  523427               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2129030427374469170']
#    seq_id  invalid_remark
# 0  523428               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225085576555']
#    seq_id  invalid_remark
# 0  523429               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224977304553']
#    seq_id  invalid_remark
# 0  523430               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224943761130']
#    seq_id  invalid_remark
# 0  523431               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224068187699']
#    seq_id  invalid_remark
# 0  523432               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224176211892']
#    seq_id  invalid_remark
# 0  523433               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224934514018']
#    seq_id  invalid_remark
# 0  523434               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224334002014']
#    seq_id  invalid_remark
# 0  523435               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224368899668']
#    seq_id  invalid_remark
# 0  523436               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225112177539']
#    seq_id  invalid_remark
# 0  523437               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225054206990']
#    seq_id  invalid_remark
# 0  523438               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 224191918398']
#    seq_id  invalid_remark
# 0  523439               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225205564454' '224849494281' '224955495496' '225102131246']
#    seq_id  invalid_remark
# 0  523440               1
# 1  523441               1
# 2  523442               1
# 3  523443               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224322490200']
#    seq_id  invalid_remark
# 0  523444               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225300873505' '224429285402']
#    seq_id  invalid_remark
# 0  523445               1
# 1  523446               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225085576555']
#    seq_id  invalid_remark
# 0  523447               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224977304553' '224943761130']
#    seq_id  invalid_remark
# 0  523448               1
# 1  523449               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224068187699']
#    seq_id  invalid_remark
# 0  523450               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224176211892']
#    seq_id  invalid_remark
# 0  523451               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224934514018' '224334002014']
#    seq_id  invalid_remark
# 0  523452               1
# 1  523453               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['224368899668']
#    seq_id  invalid_remark
# 0  523454               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225112177539' '225054206990']
#    seq_id  invalid_remark
# 0  523455               1
# 1  523456               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 帮 尽快 发货']
#    seq_id  invalid_remark
# 0  523457               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['收货 后退 邮费 10141955 迪 十一 萌']
#    seq_id  invalid_remark
# 0  523458               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['直赔 2099 元 差价 迪 小拳 20211014200433']
#    seq_id  invalid_remark
# 0  523459               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['查 换货 JDY000736582692 贵 万全 1014 电联 客户 确认 客户 已 门店 购买 不 需要 换货 直接 退款 即可 孙文婷 1014']
#    seq_id  invalid_remark
# 0  523460               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['直赔 差价 458 迪小尔 20211014200603']
#    seq_id  invalid_remark
# 0  523461               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['直赔 2099 元 差价 迪 小拳 20211014200433 已直 赔 2099 谢春燕 1014']
#    seq_id  invalid_remark
# 0  523462               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['包邮 迪小旺 10141920']
#    seq_id  invalid_remark
# 0  523463               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['直赔 差价 458 迪小尔 20211014200603 已直 赔 458 谢春燕 1014']
#    seq_id  invalid_remark
# 0  523464               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['你好 m s 俩 号 都 体验 一下 下次 知道 买 谢谢']
#    seq_id  invalid_remark
# 0  523465               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['快递 首选 申通']
#    seq_id  invalid_remark
# 0  523466               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['追回 登记 赔付 孙文婷 1014']
#    seq_id  invalid_remark
# 0  523467               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['直赔 差价 5092 迪小尔 20211014201715']
#    seq_id  invalid_remark
# 0  523468               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['直赔 差价 5092 迪小尔 20211014201715 已直 赔 5092 谢春燕 1014']
#    seq_id  invalid_remark
# 0  523469               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['红色 条纹 红色 条纹']
#    seq_id  invalid_remark
# 0  523470               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523471               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['追回 登记 赔付 孙文婷 1014']
#    seq_id  invalid_remark
# 0  523472               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523473               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1620813314372956214']
#    seq_id  invalid_remark
# 0  523474               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1620813314372956214']
#    seq_id  invalid_remark
# 0  523475               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523476               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['物流 追回 登记 赔付 孙文婷 1014']
#    seq_id  invalid_remark
# 0  523477               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1867677840600746040']
#    seq_id  invalid_remark
# 0  523478               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1867677840600746040']
#    seq_id  invalid_remark
# 0  523479               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['追回 登记 赔付 孙文婷 1014']
#    seq_id  invalid_remark
# 0  523480               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['漏水 承担 退货 迪 小心 20211014202920']
#    seq_id  invalid_remark
# 0  523481               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['已 退款 王滕滕']
#    seq_id  invalid_remark
# 0  523482               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['追回 登记 赔付 孙文婷 1014' '1408236780421349092']
#    seq_id  invalid_remark
# 0  523483               1
# 1  523484               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['已 退款 王滕滕']
#    seq_id  invalid_remark
# 0  523485               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['追回 登记 赔付 孙文婷 1014']
#    seq_id  invalid_remark
# 0  523486               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1397187180360370917']
#    seq_id  invalid_remark
# 0  523487               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1397187180360370917']
#    seq_id  invalid_remark
# 0  523488               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['收货 后退 邮费 10142033 迪十萌']
#    seq_id  invalid_remark
# 0  523489               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['缺货 补发 计 TO']
#    seq_id  invalid_remark
# 0  523490               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2158458050529736832']
#    seq_id  invalid_remark
# 0  523491               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['缺货 补发 计 TO' '追回 登记 赔付 孙文婷 1014']
#    seq_id  invalid_remark
# 0  523492               1
# 1  523493               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['质量问题 承担 运费 511010']
#    seq_id  invalid_remark
# 0  523494               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2164710385094753447']
#    seq_id  invalid_remark
# 0  523495               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['质量问题 承担 运费 511010']
#    seq_id  invalid_remark
# 0  523496               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['追回 登记 赔付 孙文婷 1014']
#    seq_id  invalid_remark
# 0  523497               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['承担 运费 邹俊吉 1010']
#    seq_id  invalid_remark
# 0  523498               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2163188448833729719']
#    seq_id  invalid_remark
# 0  523499               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['承担 运费 邹俊吉 1010']
#    seq_id  invalid_remark
# 0  523500               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['追回 登记 赔付 孙文婷 1014 收到 货 联系 直赔 差价 1499 迪小尔 20211014204129']
#    seq_id  invalid_remark
# 0  523501               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['承担 运费 邹俊吉 1010']
#    seq_id  invalid_remark
# 0  523502               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['拦截 追回 登记 赔付 迪 小心 20211014204411' '产品 质量问题']
#    seq_id  invalid_remark
# 0  523503               1
# 1  523504               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1418007685340869294']
#    seq_id  invalid_remark
# 0  523505               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['产品 质量问题']
#    seq_id  invalid_remark
# 0  523506               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['要发 申通 顺丰' '区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523507               1
# 1  523508               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['收货 后退 差价 10 元 10142042 迪 十二 萌']
#    seq_id  invalid_remark
# 0  523509               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2049891760960432112']
#    seq_id  invalid_remark
# 0  523510               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2049891760960432112']
#    seq_id  invalid_remark
# 0  523511               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['反馈 没有 收到 球拍 已登记 仓库 核实 迪小尔 20211014205409']
#    seq_id  invalid_remark
# 0  523512               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523513               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['麻烦 仔细检查 后 尽快 发货 谢谢']
#    seq_id  invalid_remark
# 0  523514               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225433762438 错漏 发 补发']
#    seq_id  invalid_remark
# 0  523515               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['225433762438 错漏 发 补发']
#    seq_id  invalid_remark
# 0  523516               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['车灯 带 破损 质保 承担 退换 迪 小心 20211008091742 维修 单无 物流 电联 未 接通 已 留言 贵 万全 108 已直 赔 退货 运费 9 谢春燕 1014']
#    seq_id  invalid_remark
# 0  523517               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1416651348990667283']
#    seq_id  invalid_remark
# 0  523518               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1416651348990667283']
#    seq_id  invalid_remark
# 0  523519               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1412912065591616489']
#    seq_id  invalid_remark
# 0  523520               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1412912065591616489']
#    seq_id  invalid_remark
# 0  523521               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2174561967859781957']
#    seq_id  invalid_remark
# 0  523522               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2174561967859781957']
#    seq_id  invalid_remark
# 0  523523               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1414113600170690785']
#    seq_id  invalid_remark
# 0  523524               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1414113600170690785']
#    seq_id  invalid_remark
# 0  523525               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1621725985946436207']
#    seq_id  invalid_remark
# 0  523526               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['1621725985946436207']
#    seq_id  invalid_remark
# 0  523527               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2027485694423452256']
#    seq_id  invalid_remark
# 0  523528               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2027485694423452256']
#    seq_id  invalid_remark
# 0  523529               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['亲请 包装 严实 避免 运输 途中 磕磕碰碰 非常感谢']
#    seq_id  invalid_remark
# 0  523530               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['差价 1649 元待直 赔迪 小心 20211014210828']
#    seq_id  invalid_remark
# 0  523531               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['急需']
#    seq_id  invalid_remark
# 0  523532               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['价格 未 生成 到手 价退 差价 迪 小拳 20211014211033']
#    seq_id  invalid_remark
# 0  523533               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['不要 发 中通']
#    seq_id  invalid_remark
# 0  523534               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['邮政 快递 申通 快递 都行 谢谢']
#    seq_id  invalid_remark
# 0  523535               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发货 之前 检查 好 再 发货 谢谢']
#    seq_id  invalid_remark
# 0  523536               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523538               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['可退 运费 7 元 511014']
#    seq_id  invalid_remark
# 0  523539               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['城 次日 达']
#    seq_id  invalid_remark
# 0  523540               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请发 顺丰 快 谢谢']
#    seq_id  invalid_remark
# 0  523541               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['检查 好 再 发货']
#    seq_id  invalid_remark
# 0  523543               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523544               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['直播间 福利']
#    seq_id  invalid_remark
# 0  523545               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['不要 百世 快递 送']
#    seq_id  invalid_remark
# 0  523546               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['亲请 尽快 发货 质量 最好 谢谢']
#    seq_id  invalid_remark
# 0  523547               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523548               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 尽快 发货 谢谢']
#    seq_id  invalid_remark
# 0  523549               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 发近 段 日期 谢谢']
#    seq_id  invalid_remark
# 0  523550               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['务必 明天']
#    seq_id  invalid_remark
# 0  523551               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['不用 打电话 直接 放洪阳 百货']
#    seq_id  invalid_remark
# 0  523552               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['明日 15 日请 发货 谢谢']
#    seq_id  invalid_remark
# 0  523553               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 顺丰 快递 不 送到 门']
#    seq_id  invalid_remark
# 0  523554               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发货前 请 检查 质量 完好 无 破损 瑕疵 污渍 颜色 尺码 不要 发错 烦请 包裹 包 结实 防水 非常感谢']
#    seq_id  invalid_remark
# 0  523555               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发 顺丰']
#    seq_id  invalid_remark
# 0  523556               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['早上 顺丰 当天']
#    seq_id  invalid_remark
# 0  523557               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请发 邮政 快递 EMS']
#    seq_id  invalid_remark
# 0  523558               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['麻烦 发货前 检查一下 谢谢']
#    seq_id  invalid_remark
# 0  523559               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['拍下 货发']
#    seq_id  invalid_remark
# 0  523560               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['速 发货 谢谢']
#    seq_id  invalid_remark
# 0  523561               1
# database is updated!
# ...
# 0  523718               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['77']
#    seq_id  invalid_remark
# 0  523719               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发货前 帮忙 调 好 时间 日期']
#    seq_id  invalid_remark
# 0  523720               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请勿 发 韵达 地区 韵达 多日 问题 极大 可能 退货']
#    seq_id  invalid_remark
# 0  523721               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['第二件 M 号']
#    seq_id  invalid_remark
# 0  523722               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['下周一 秋游 麻烦 帮 快点 发货 谢谢']
#    seq_id  invalid_remark
# 0  523723               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 帮 检查 好 谢谢']
#    seq_id  invalid_remark
# 0  523724               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 当天 件 谢谢']
#    seq_id  invalid_remark
# 0  523725               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['顺丰 当天 件']
#    seq_id  invalid_remark
# 0  523726               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['确保 品质 我迪卡 侬 老 顾客 以前 上海 常去 迪卡侬 购物']
#    seq_id  invalid_remark
# 0  523727               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['不要 申通 快递']
#    seq_id  invalid_remark
# 0  523728               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['希望 能发 新款']
#    seq_id  invalid_remark
# 0  523729               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发 邮政']
#    seq_id  invalid_remark
# 0  523730               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['全新 工商局 工作']
#    seq_id  invalid_remark
# 0  523731               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请发 中通 顺丰 快递']
#    seq_id  invalid_remark
# 0  523732               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['放丰巢 快递柜 谢谢']
#    seq_id  invalid_remark
# 0  523733               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发 顺丰']
#    seq_id  invalid_remark
# 0  523734               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['老板 麻烦 发货前 检查 仔细 不要 瑕疵 残次品 包装 结实 点 尽快 发货 谢谢']
#    seq_id  invalid_remark
# 0  523735               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发 新款']
#    seq_id  invalid_remark
# 0  523736               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523737               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523738               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 不要 发 中通 中通 停运']
#    seq_id  invalid_remark
# 0  523739               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523740               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['麻烦 店家 挑选 崭新 无损 宝贝 包装 厚实 谢谢']
#    seq_id  invalid_remark
# 0  523741               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发货前 请 仔细检查 质量 包装 结实 点']
#    seq_id  invalid_remark
# 0  523742               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523743               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523744               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请发 新款']
#    seq_id  invalid_remark
# 0  523745               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['尽快 发货']
#    seq_id  invalid_remark
# 0  523746               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['优先 圆通 邮政']
#    seq_id  invalid_remark
# 0  523747               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523748               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['保证质量 尽快 发货']
#    seq_id  invalid_remark
# 0  523749               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['确保 质量 包装 严实']
#    seq_id  invalid_remark
# 0  523750               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['默认 快递' '区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523751               1
# 1  523752               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['包装 后 一点 不要 坡']
#    seq_id  invalid_remark
# 0  523753               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['你好 帮 检查一下 不要 瑕疵 谢谢']
#    seq_id  invalid_remark
# 0  523754               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 认真 验货 及时 发货 谢谢']
#    seq_id  invalid_remark
# 0  523755               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['全新 无损 非 退换货 注意 包装']
#    seq_id  invalid_remark
# 0  523756               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['下周一 发货']
#    seq_id  invalid_remark
# 0  523757               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请 尽快 发货 谢谢 老师']
#    seq_id  invalid_remark
# 0  523758               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['急用 请 卖家 选择 顺丰 补 运费 差价']
#    seq_id  invalid_remark
# 0  523759               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['请勿 发错 谢谢']
#    seq_id  invalid_remark
# 0  523760               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['不要 申通 不要 申通 不要 申通']
#    seq_id  invalid_remark
# 0  523761               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发 圆通 最好']
#    seq_id  invalid_remark
# 0  523762               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2168344695105962935']
#    seq_id  invalid_remark
# 0  523763               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['2168344695105962935']
#    seq_id  invalid_remark
# 0  523764               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['可退 运费 5 元 511015']
#    seq_id  invalid_remark
# 0  523765               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['已登记 dass 报修' '人要 下午 七点 才 在家 帮 挂 门上 好 谢谢' '请 检查 包装 好 再 发货']
#    seq_id  invalid_remark
# 0  523767               1
# 1  523768               1
# 2  523769               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['收货 后退 差价 24 元']
#    seq_id  invalid_remark
# 0  523770               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523771               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退回 信息 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523772               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523773               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['周一 发货']
#    seq_id  invalid_remark
# 0  523774               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退回 信息 退款 贵 万全 1015' '区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523775               1
# 1  523776               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['检查 好 尺码 质量']
#    seq_id  invalid_remark
# 0  523777               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退回 信息 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523778               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['已 反馈 修改 地址 迪小趣 20211015092205']
#    seq_id  invalid_remark
# 0  523779               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['门店 配送 希望 今日 达 谢谢']
#    seq_id  invalid_remark
# 0  523780               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发货前 麻烦 检查 仔细 不要 瑕疵 残次品 包装 结实 点 尽快 发货 谢谢' '退回 登记 物流 赔付 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523781               1
# 1  523782               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['尽量 不要 圆通 谢谢']
#    seq_id  invalid_remark
# 0  523783               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['收到 货退 差价' '退回 登记 物流 赔付 退回 信息 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523784               1
# 1  523785               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发货前 请 检查 宝贝 质量 不要 破损 谢谢' '退回 登记 物流 赔付 退回 信息 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523786               1
# 1  523787               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523788               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['已登记 补发 第三节 配件']
#    seq_id  invalid_remark
# 0  523789               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523790               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['差价 可退 张庆菊 1015']
#    seq_id  invalid_remark
# 0  523791               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退回 信息 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523792               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['包邮']
#    seq_id  invalid_remark
# 0  523793               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['不要 残次品 不要 残次品 不要 残次品 包装 仔细 谢谢']
#    seq_id  invalid_remark
# 0  523794               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退回 信息 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523795               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['发 旧版']
#    seq_id  invalid_remark
# 0  523796               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['cn2066816352']
#    seq_id  invalid_remark
# 0  523797               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['cn2066816352']
#    seq_id  invalid_remark
# 0  523798               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退回 信息 退款 贵 万全 1015']
#    seq_id  invalid_remark
# 0  523799               0
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['区域 零售 蜂鸟']
#    seq_id  invalid_remark
# 0  523800               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['退回 登记 物流 赔付 退回 信息 退款 贵 万全 1015' 'cn2096679101']
#    seq_id  invalid_remark
# 0  523801               1
# 1  523802               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
# clean_text: ['cn2096679101' '包邮']
#    seq_id  invalid_remark
# 0  523803               1
# 1  523804               1
# database is updated!
# Save max seq_id in file
# -------------------------------------------------------------------------
